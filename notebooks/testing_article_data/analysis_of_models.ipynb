# %%
TRAINING_HIST_PATH = 'C:/Users/leona/Documents/Mestrado/nano-optics-ml/src/saved_training_history'

# %%
import glob, json, os, re
import pandas as pd

# Updated regex: allow optional scientific notation (e.g. 1e-05) for lr and wgtdecay
pattern = re.compile(
    r'(?P<model>[A-Za-z0-9]+)_'
    r'lr(?P<lr>[\d\.]+(?:e[+-]?\d+)?)_'              
    r'bs(?P<bs>\d+)_'
    r'epochs(?P<epochs>\d+)_'
    r'wgtdecay(?P<wgtdecay>[\d\.]+(?:e[+-]?\d+)?)_'  
    r'hidden_size(?P<hidden_size>\d+)_'
    r'num_hidden_layers(?P<num_hidden_layers>\d+)_'
    r'(?P<date>\d{8})_(?P<time>\d{6})\.json$'
)

rows = []
for filepath in glob.glob("C:/Users/leona/Documents/Mestrado/nano-optics-ml/src/saved_training_history/*.json"):
    fname = os.path.basename(filepath)
    m = pattern.match(fname)
    if not m:
        print(f"Skipping {fname}")
        continue

    params = m.groupdict()
    # parse run datetime
    params['run_datetime'] = pd.to_datetime(
        params['date'] + params['time'], format="%Y%m%d%H%M%S"
    )

    # convert everything numeric to the correct type
    params['lr'] = float(params['lr'])
    params['wgtdecay'] = float(params['wgtdecay'])
    for int_field in ('bs','epochs','hidden_size','num_hidden_layers'):
        params[int_field] = int(params[int_field])

    # load the JSON history
    with open(filepath) as f:
        history = json.load(f)

    # build per-epoch DataFrame
    df_hist = (
        pd.DataFrame.from_dict(history, orient='index')
          .rename_axis('epoch')
          .reset_index()
          .astype({'epoch': int})
    )

    # pick out the final epoch
    last = df_hist.loc[df_hist['epoch'].idxmax(), ['epoch','loss','test_loss']]

    # combine into one row
    row = {
        **params,
        'final_epoch': int(last['epoch']),
        'final_loss': float(last['loss']),
        'final_test_loss': float(last['test_loss']),
        'file_name':fname,
    }
    rows.append(row)

# assemble the summary DataFrame
df_summary = pd.DataFrame(rows).sort_values(
    ['model','run_datetime']
).reset_index(drop=True)

print(df_summary)
# Out:
#     model      lr   bs  epochs  wgtdecay  hidden_size  num_hidden_layers  \
# 0     HNN  0.0010    8     500   0.00001            8                  3
# 1     HNN  0.0010    8     500   0.00001           16                  3
# 2     HNN  0.0010    8     500   0.00010            8                  3
# 3     HNN  0.0010    8     500   0.00010           16                  3
# 4     HNN  0.0010    8     500   0.00100            8                  3
# ..    ...     ...  ...     ...       ...          ...                ...
# 472    NN  0.0001  512    7000   0.00001           16                  3
# 473    NN  0.0001  512    7000   0.00010            8                  3
# 474    NN  0.0001  512    7000   0.00010           16                  3
# 475    NN  0.0001  512    7000   0.00100            8                  3
# 476    NN  0.0001  512    7000   0.00100           16                  3
#
#          date    time        run_datetime  final_epoch  final_loss  \
# 0    20250414  040447 2025-04-14 04:04:47          500    0.091946
# 1    20250414  040637 2025-04-14 04:06:37          500    0.045268
# 2    20250414  040828 2025-04-14 04:08:28          500    0.107477
# 3    20250414  041018 2025-04-14 04:10:18          500    0.070384
# 4    20250414  041208 2025-04-14 04:12:08          500    0.336463
# ..        ...     ...                 ...          ...         ...
# 472  20250414  035623 2025-04-14 03:56:23         7000    0.133678
# 473  20250414  035802 2025-04-14 03:58:02         7000    0.516260
# 474  20250414  035942 2025-04-14 03:59:42         7000    0.125242
# 475  20250414  040119 2025-04-14 04:01:19         7000    0.968620
# 476  20250414  040256 2025-04-14 04:02:56         7000    1.000007
#
#      final_test_loss                                          file_name
# 0           0.106730  HNN_lr0.001_bs8_epochs500_wgtdecay1e-05_hidden...
# 1           0.064064  HNN_lr0.001_bs8_epochs500_wgtdecay1e-05_hidden...
# 2           0.116764  HNN_lr0.001_bs8_epochs500_wgtdecay0.0001_hidde...
# 3           0.081681  HNN_lr0.001_bs8_epochs500_wgtdecay0.0001_hidde...
# 4           0.422485  HNN_lr0.001_bs8_epochs500_wgtdecay0.001_hidden...
# ..               ...                                                ...
# 472         0.152223  NN_lr0.0001_bs512_epochs7000_wgtdecay1e-05_hid...
# 473         0.614370  NN_lr0.0001_bs512_epochs7000_wgtdecay0.0001_hi...
# 474         0.150072  NN_lr0.0001_bs512_epochs7000_wgtdecay0.0001_hi...
# 475         1.171745  NN_lr0.0001_bs512_epochs7000_wgtdecay0.001_hid...
# 476         1.201619  NN_lr0.0001_bs512_epochs7000_wgtdecay0.001_hid...
#
# [477 rows x 14 columns]

# %%
df_summary.query("""model == 'NN'""").sort_values(['final_test_loss']).reset_index(drop=True).head(30)
# Out:
#    model      lr   bs  epochs  wgtdecay  hidden_size  num_hidden_layers  \
# 0     NN  0.0010    8    7000   0.00001           16                  3
# 1     NN  0.0005    8    7000   0.00001           16                  3
# 2     NN  0.0010    8    5000   0.00001           16                  3
# 3     NN  0.0010   32    5000   0.00001           16                  3
# 4     NN  0.0010    8    7000   0.00001            8                  3
# 5     NN  0.0005    8    5000   0.00001           16                  3
# 6     NN  0.0005   16    5000   0.00001           16                  3
# 7     NN  0.0010  128    7000   0.00001           16                  3
# 8     NN  0.0005   16    7000   0.00001           16                  3
# 9     NN  0.0010   16    7000   0.00001           16                  3
# 10    NN  0.0005   32    5000   0.00001           16                  3
# 11    NN  0.0010    8    5000   0.00001            8                  3
# 12    NN  0.0010   32    7000   0.00001            8                  3
# 13    NN  0.0010   16    5000   0.00001           16                  3
# 14    NN  0.0010  128    5000   0.00001           16                  3
# 15    NN  0.0010   16    7000   0.00001            8                  3
# 16    NN  0.0010  512    7000   0.00001           16                  3
# 17    NN  0.0005   32    7000   0.00001           16                  3
# 18    NN  0.0010    8    7000   0.00010           16                  3
# 19    NN  0.0010  256    7000   0.00001           16                  3
# 20    NN  0.0005    8    2000   0.00001           16                  3
# 21    NN  0.0010   16    7000   0.00010           16                  3
# 22    NN  0.0010    8    5000   0.00010           16                  3
# 23    NN  0.0010   32    7000   0.00010           16                  3
# 24    NN  0.0010   32    2000   0.00001           16                  3
# 25    NN  0.0010   16    5000   0.00001            8                  3
# 26    NN  0.0010  512    5000   0.00001           16                  3
# 27    NN  0.0005  128    7000   0.00001           16                  3
# 28    NN  0.0005    8    5000   0.00001            8                  3
# 29    NN  0.0005   16    7000   0.00001            8                  3
#
#         date    time        run_datetime  final_epoch  final_loss  \
# 0   20250412  230722 2025-04-12 23:07:22         7000    0.011369
# 1   20250413  094956 2025-04-13 09:49:56         7000    0.011869
# 2   20250412  210423 2025-04-12 21:04:23         5000    0.011736
# 3   20250413  035536 2025-04-13 03:55:36         5000    0.013843
# 4   20250412  224216 2025-04-12 22:42:16         7000    0.018938
# 5   20250413  074746 2025-04-13 07:47:46         5000    0.015321
# 6   20250413  121642 2025-04-13 12:16:42         5000    0.017470
# 7   20250413  052247 2025-04-13 05:22:47         7000    0.023957
# 8   20250413  132046 2025-04-13 13:20:46         7000    0.019194
# 9   20250413  023722 2025-04-13 02:37:22         7000    0.009982
# 10  20250413  143941 2025-04-13 14:39:41         5000    0.026981
# 11  20250412  204632 2025-04-12 20:46:32         5000    0.032721
# 12  20250413  042327 2025-04-13 04:23:27         7000    0.036169
# 13  20250413  013323 2025-04-13 01:33:23         5000    0.012584
# 14  20250413  050933 2025-04-13 05:09:33         5000    0.018292
# 15  20250413  022417 2025-04-13 02:24:17         7000    0.029569
# 16  20250413  061229 2025-04-13 06:12:29         7000    0.036431
# 17  20250413  151509 2025-04-13 15:15:09         7000    0.027524
# 18  20250412  235702 2025-04-12 23:57:02         7000    0.029465
# 19  20250413  055047 2025-04-13 05:50:47         7000    0.017958
# 20  20250413  064352 2025-04-13 06:43:52         2000    0.035731
# 21  20250413  030333 2025-04-13 03:03:33         7000    0.028568
# 22  20250412  214006 2025-04-12 21:40:06         5000    0.031441
# 23  20250413  044511 2025-04-13 04:45:11         7000    0.040282
# 24  20250413  033700 2025-04-13 03:37:00         2000    0.034868
# 25  20250413  012402 2025-04-13 01:24:02         5000    0.022180
# 26  20250413  060441 2025-04-13 06:04:41         5000    0.041820
# 27  20250413  160748 2025-04-13 16:07:48         7000    0.034518
# 28  20250413  073000 2025-04-13 07:30:00         5000    0.023544
# 29  20250413  130733 2025-04-13 13:07:33         7000    0.033856
#
#     final_test_loss                                          file_name
# 0          0.017902  NN_lr0.001_bs8_epochs7000_wgtdecay1e-05_hidden...
# 1          0.020131  NN_lr0.0005_bs8_epochs7000_wgtdecay1e-05_hidde...
# 2          0.022787  NN_lr0.001_bs8_epochs5000_wgtdecay1e-05_hidden...
# 3          0.024358  NN_lr0.001_bs32_epochs5000_wgtdecay1e-05_hidde...
# 4          0.025201  NN_lr0.001_bs8_epochs7000_wgtdecay1e-05_hidden...
# 5          0.026479  NN_lr0.0005_bs8_epochs5000_wgtdecay1e-05_hidde...
# 6          0.028196  NN_lr0.0005_bs16_epochs5000_wgtdecay1e-05_hidd...
# 7          0.029287  NN_lr0.001_bs128_epochs7000_wgtdecay1e-05_hidd...
# 8          0.029805  NN_lr0.0005_bs16_epochs7000_wgtdecay1e-05_hidd...
# 9          0.030205  NN_lr0.001_bs16_epochs7000_wgtdecay1e-05_hidde...
# 10         0.031413  NN_lr0.0005_bs32_epochs5000_wgtdecay1e-05_hidd...
# 11         0.035787  NN_lr0.001_bs8_epochs5000_wgtdecay1e-05_hidden...
# 12         0.037091  NN_lr0.001_bs32_epochs7000_wgtdecay1e-05_hidde...
# 13         0.037521  NN_lr0.001_bs16_epochs5000_wgtdecay1e-05_hidde...
# 14         0.037747  NN_lr0.001_bs128_epochs5000_wgtdecay1e-05_hidd...
# 15         0.039049  NN_lr0.001_bs16_epochs7000_wgtdecay1e-05_hidde...
# 16         0.040278  NN_lr0.001_bs512_epochs7000_wgtdecay1e-05_hidd...
# 17         0.040807  NN_lr0.0005_bs32_epochs7000_wgtdecay1e-05_hidd...
# 18         0.041087  NN_lr0.001_bs8_epochs7000_wgtdecay0.0001_hidde...
# 19         0.041281  NN_lr0.001_bs256_epochs7000_wgtdecay1e-05_hidd...
# 20         0.042039  NN_lr0.0005_bs8_epochs2000_wgtdecay1e-05_hidde...
# 21         0.042175  NN_lr0.001_bs16_epochs7000_wgtdecay0.0001_hidd...
# 22         0.042306  NN_lr0.001_bs8_epochs5000_wgtdecay0.0001_hidde...
# 23         0.042778  NN_lr0.001_bs32_epochs7000_wgtdecay0.0001_hidd...
# 24         0.042894  NN_lr0.001_bs32_epochs2000_wgtdecay1e-05_hidde...
# 25         0.045080  NN_lr0.001_bs16_epochs5000_wgtdecay1e-05_hidde...
# 26         0.045136  NN_lr0.001_bs512_epochs5000_wgtdecay1e-05_hidd...
# 27         0.045903  NN_lr0.0005_bs128_epochs7000_wgtdecay1e-05_hid...
# 28         0.046057  NN_lr0.0005_bs8_epochs5000_wgtdecay1e-05_hidde...
# 29         0.046115  NN_lr0.0005_bs16_epochs7000_wgtdecay1e-05_hidd...

# %%
df_summary.query("""model == 'HNN'""").sort_values(['final_test_loss']).reset_index(drop=True)
# Out:
#    model     lr  bs  epochs  wgtdecay  hidden_size  num_hidden_layers  \
# 0    HNN  0.001   8    7000   0.00001           16                  3
# 1    HNN  0.001   8    5000   0.00001           16                  3
# 2    HNN  0.001  32    5000   0.00001           16                  3
# 3    HNN  0.001  32    7000   0.00001           16                  3
# 4    HNN  0.001   8    2000   0.00001           16                  3
# 5    HNN  0.001   8    5000   0.00010           16                  3
# 6    HNN  0.001   8    5000   0.00001            8                  3
# 7    HNN  0.001  32    7000   0.00001            8                  3
# 8    HNN  0.001  32    5000   0.00010           16                  3
# 9    HNN  0.001   8    7000   0.00010           16                  3
# 10   HNN  0.001   8    7000   0.00001            8                  3
# 11   HNN  0.001   8     500   0.00001           16                  3
# 12   HNN  0.001   8    7000   0.00010            8                  3
# 13   HNN  0.001  32    7000   0.00010           16                  3
# 14   HNN  0.001   8    2000   0.00001            8                  3
# 15   HNN  0.001   8     500   0.00001           16                  3
# 16   HNN  0.001   8    5000   0.00010            8                  3
# 17   HNN  0.001  32    5000   0.00001            8                  3
# 18   HNN  0.001   8     500   0.00010           16                  3
# 19   HNN  0.001  32    7000   0.00010            8                  3
# 20   HNN  0.001  32    5000   0.00010            8                  3
# 21   HNN  0.001   8     500   0.00010           16                  3
# 22   HNN  0.001  32     500   0.00001           16                  3
# 23   HNN  0.001   8     500   0.00001            8                  3
# 24   HNN  0.001   8     500   0.00010            8                  3
# 25   HNN  0.001   8     500   0.00001            8                  3
# 26   HNN  0.001   8     500   0.00010            8                  3
# 27   HNN  0.001  32     500   0.00010           16                  3
# 28   HNN  0.001  32     500   0.00001            8                  3
# 29   HNN  0.001  32     500   0.00010            8                  3
# 30   HNN  0.001   8    5000   0.00100           16                  3
# 31   HNN  0.001   8     500   0.00100            8                  3
# 32   HNN  0.001   8     500   0.00100            8                  3
# 33   HNN  0.001   8    7000   0.00100           16                  3
# 34   HNN  0.001  32    5000   0.00100            8                  3
# 35   HNN  0.001  32     500   0.00100           16                  3
# 36   HNN  0.001  32     500   0.00100            8                  3
# 37   HNN  0.001   8    5000   0.00100            8                  3
# 38   HNN  0.001   8    7000   0.00100            8                  3
# 39   HNN  0.001  32    7000   0.00100            8                  3
# 40   HNN  0.001  32    5000   0.00100           16                  3
# 41   HNN  0.001   8     500   0.00100           16                  3
# 42   HNN  0.001   8     500   0.00100           16                  3
#
#         date    time        run_datetime  final_epoch  final_loss  \
# 0   20250417  123531 2025-04-17 12:35:31         7000    0.007487
# 1   20250417  102631 2025-04-17 10:26:31         5000    0.009985
# 2   20250417  144157 2025-04-17 14:41:57         5000    0.009236
# 3   20250417  153325 2025-04-17 15:33:25         7000    0.012272
# 4   20250414  043028 2025-04-14 04:30:28         2000    0.016132
# 5   20250417  110013 2025-04-17 11:00:13         5000    0.026501
# 6   20250417  100920 2025-04-17 10:09:20         5000    0.019552
# 7   20250417  152406 2025-04-17 15:24:06         7000    0.019890
# 8   20250417  145720 2025-04-17 14:57:20         5000    0.036021
# 9   20250417  133155 2025-04-17 13:31:55         7000    0.029154
# 10  20250417  120813 2025-04-17 12:08:13         7000    0.025319
# 11  20250414  040637 2025-04-14 04:06:37          500    0.045268
# 12  20250417  130317 2025-04-17 13:03:17         7000    0.044998
# 13  20250417  155028 2025-04-17 15:50:28         7000    0.044764
# 14  20250414  042131 2025-04-14 04:21:31         2000    0.042289
# 15  20250417  094558 2025-04-17 09:45:58          500    0.059247
# 16  20250417  104344 2025-04-17 10:43:44         5000    0.052526
# 17  20250417  143640 2025-04-17 14:36:40         5000    0.060714
# 18  20250414  041018 2025-04-14 04:10:18          500    0.070384
# 19  20250417  154053 2025-04-17 15:40:53         7000    0.064758
# 20  20250417  144934 2025-04-17 14:49:34         5000    0.071819
# 21  20250417  094920 2025-04-17 09:49:20          500    0.088606
# 22  20250417  142934 2025-04-17 14:29:34          500    0.087749
# 23  20250414  040447 2025-04-14 04:04:47          500    0.091946
# 24  20250417  094739 2025-04-17 09:47:39          500    0.100130
# 25  20250417  094417 2025-04-17 09:44:17          500    0.087458
# 26  20250414  040828 2025-04-14 04:08:28          500    0.107477
# 27  20250417  143038 2025-04-17 14:30:38          500    0.102923
# 28  20250417  142901 2025-04-17 14:29:01          500    0.168052
# 29  20250417  143006 2025-04-17 14:30:06          500    0.177478
# 30  20250417  113929 2025-04-17 11:39:29         5000    0.336895
# 31  20250417  095102 2025-04-17 09:51:02          500    0.336336
# 32  20250414  041208 2025-04-14 04:12:08          500    0.336463
# 33  20250417  142827 2025-04-17 14:28:27         7000    0.336940
# 34  20250417  150507 2025-04-17 15:05:07         5000    0.336130
# 35  20250417  143142 2025-04-17 14:31:42          500    0.336828
# 36  20250417  143109 2025-04-17 14:31:09          500    0.336282
# 37  20250417  111833 2025-04-17 11:18:33         5000    0.336113
# 38  20250417  140000 2025-04-17 14:00:00         7000    0.336534
# 39  20250417  155843 2025-04-17 15:58:43         7000    0.336095
# 40  20250417  151302 2025-04-17 15:13:02         5000    0.336040
# 41  20250417  095246 2025-04-17 09:52:46          500    0.336969
# 42  20250414  041358 2025-04-14 04:13:58          500    0.336526
#
#     final_test_loss                                          file_name
# 0          0.026053  HNN_lr0.001_bs8_epochs7000_wgtdecay1e-05_hidde...
# 1          0.031324  HNN_lr0.001_bs8_epochs5000_wgtdecay1e-05_hidde...
# 2          0.032221  HNN_lr0.001_bs32_epochs5000_wgtdecay1e-05_hidd...
# 3          0.034499  HNN_lr0.001_bs32_epochs7000_wgtdecay1e-05_hidd...
# 4          0.034640  HNN_lr0.001_bs8_epochs2000_wgtdecay1e-05_hidde...
# 5          0.040609  HNN_lr0.001_bs8_epochs5000_wgtdecay0.0001_hidd...
# 6          0.043488  HNN_lr0.001_bs8_epochs5000_wgtdecay1e-05_hidde...
# 7          0.049106  HNN_lr0.001_bs32_epochs7000_wgtdecay1e-05_hidd...
# 8          0.052979  HNN_lr0.001_bs32_epochs5000_wgtdecay0.0001_hid...
# 9          0.057214  HNN_lr0.001_bs8_epochs7000_wgtdecay0.0001_hidd...
# 10         0.058576  HNN_lr0.001_bs8_epochs7000_wgtdecay1e-05_hidde...
# 11         0.064064  HNN_lr0.001_bs8_epochs500_wgtdecay1e-05_hidden...
# 12         0.066796  HNN_lr0.001_bs8_epochs7000_wgtdecay0.0001_hidd...
# 13         0.068775  HNN_lr0.001_bs32_epochs7000_wgtdecay0.0001_hid...
# 14         0.069635  HNN_lr0.001_bs8_epochs2000_wgtdecay1e-05_hidde...
# 15         0.076564  HNN_lr0.001_bs8_epochs500_wgtdecay1e-05_hidden...
# 16         0.078137  HNN_lr0.001_bs8_epochs5000_wgtdecay0.0001_hidd...
# 17         0.078193  HNN_lr0.001_bs32_epochs5000_wgtdecay1e-05_hidd...
# 18         0.081681  HNN_lr0.001_bs8_epochs500_wgtdecay0.0001_hidde...
# 19         0.087714  HNN_lr0.001_bs32_epochs7000_wgtdecay0.0001_hid...
# 20         0.088776  HNN_lr0.001_bs32_epochs5000_wgtdecay0.0001_hid...
# 21         0.093915  HNN_lr0.001_bs8_epochs500_wgtdecay0.0001_hidde...
# 22         0.099352  HNN_lr0.001_bs32_epochs500_wgtdecay1e-05_hidde...
# 23         0.106730  HNN_lr0.001_bs8_epochs500_wgtdecay1e-05_hidden...
# 24         0.110527  HNN_lr0.001_bs8_epochs500_wgtdecay0.0001_hidde...
# 25         0.112138  HNN_lr0.001_bs8_epochs500_wgtdecay1e-05_hidden...
# 26         0.116764  HNN_lr0.001_bs8_epochs500_wgtdecay0.0001_hidde...
# 27         0.117094  HNN_lr0.001_bs32_epochs500_wgtdecay0.0001_hidd...
# 28         0.214380  HNN_lr0.001_bs32_epochs500_wgtdecay1e-05_hidde...
# 29         0.225578  HNN_lr0.001_bs32_epochs500_wgtdecay0.0001_hidd...
# 30         0.422070  HNN_lr0.001_bs8_epochs5000_wgtdecay0.001_hidde...
# 31         0.422254  HNN_lr0.001_bs8_epochs500_wgtdecay0.001_hidden...
# 32         0.422485  HNN_lr0.001_bs8_epochs500_wgtdecay0.001_hidden...
# 33         0.422949  HNN_lr0.001_bs8_epochs7000_wgtdecay0.001_hidde...
# 34         0.422973  HNN_lr0.001_bs32_epochs5000_wgtdecay0.001_hidd...
# 35         0.423056  HNN_lr0.001_bs32_epochs500_wgtdecay0.001_hidde...
# 36         0.423131  HNN_lr0.001_bs32_epochs500_wgtdecay0.001_hidde...
# 37         0.423289  HNN_lr0.001_bs8_epochs5000_wgtdecay0.001_hidde...
# 38         0.423588  HNN_lr0.001_bs8_epochs7000_wgtdecay0.001_hidde...
# 39         0.423665  HNN_lr0.001_bs32_epochs7000_wgtdecay0.001_hidd...
# 40         0.423943  HNN_lr0.001_bs32_epochs5000_wgtdecay0.001_hidd...
# 41         0.424357  HNN_lr0.001_bs8_epochs500_wgtdecay0.001_hidden...
# 42         0.425980  HNN_lr0.001_bs8_epochs500_wgtdecay0.001_hidden...
